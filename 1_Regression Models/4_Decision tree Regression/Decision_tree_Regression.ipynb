# %% [markdown]
# ===>Decision Tree Regression :----->

# %% [markdown]
# ==> Importing Libraries :--->

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ==>Importing the Dataset :--->

# %%
dataset = pd.read_csv("Position_Salaries.csv")
x = dataset.iloc [: , 1:-1].values
y = dataset.iloc [:, -1].values

# %% [markdown]
# ==> Training the Decission tree regression model on the whole dataset :--->

# %%
from sklearn.tree import DecisionTreeRegressor  
regressor = DecisionTreeRegressor(random_state=0)  

regressor.fit(x , y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ==> Predicting a new result :--->

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# ==>Visualizing the decision tree regression results (first 2 lines is to get high resolution) :--->

# %%
x_grid = np.arange(min(x), max(x), 0.1)  

x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x,y, color = 'red')
plt.plot(x_grid, regressor.predict(x_grid), color = 'blue')
plt.title("Truth or Bluff (Decission Tree Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
# Out:
# C:\Users\Tarak Bandhara\AppData\Local\Temp\ipykernel_23472\3396075384.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)
